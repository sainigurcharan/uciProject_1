# %%
import numpy as np
import pandas as pd

# %%
terrorRaw = pd.read_csv('GTD_Data/globalterrorismdb_0718dist.csv', encoding='ISO-8859-1')
terrorRaw.head()
# Out:
# C:\Users\saini\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %%
terror0717 = terrorRaw[(terrorRaw["iyear"] >= 2007) & (terrorRaw["iyear"] <= 2019)]
terror0717.head()
# Out:
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 82108  200701010001   2007       1     1        NaN         1   1/8/2007
# 82109  200701010002   2007       1     1        NaN         0        NaN
# 82110  200701010003   2007       1     1        NaN         0        NaN
# 82111  200701010004   2007       1     1        NaN         0        NaN
# 82112  200701010005   2007       1     1        NaN         0        NaN
#
#        country               country_txt  region  ...  \
# 82108      155  West Bank and Gaza Strip      10  ...
# 82109      205                  Thailand       5  ...
# 82110      186                 Sri Lanka       6  ...
# 82111        4               Afghanistan       6  ...
# 82112      153                  Pakistan       6  ...
#
#                                                 addnotes  \
# 82108                                                NaN
# 82109                                                NaN
# ...

# %%
terrorRaw.info()
terror0717.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99583 entries, 82108 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 103.3+ MB

# %%
terror0717.to_csv('GTD_Data/gtd_0717.csv')
